# %% [markdown]
# ### Implementing character-level LSTM text generation
#
# Start by using Nietzsche's writings to learn a language model. It's going to be specifically a model of his writing style and topics, rather than a generic model of the English language.

# %%
import keras
import numpy as np
from keras import layers
import random
import sys

# %%
#download and parse the initial text file

path = keras.utils.get_file('nietzsche.txt',origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %% [markdown]
# #### Vectorize overlapping sequences of characters using one-hot encoding

# %%
# Length of extracted character sequences
maxlen = 60

#sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text)-maxlen, step):
  sentences.append(text[i:i+maxlen])
  next_chars.append(text[i+maxlen])
  
print ('Number of sequences:',len(sentences))

#List of unique characters in corpus
chars = sorted(list(set(text)))   
print ('Unique characters:',len(chars))
#dictionary to map unique characters to their index for easy lookup
char_indices = dict((char,chars.index(char)) for char in chars) 

print('Vectorization...')
#One hot encode the characters into binary arrays
x = np.zeros((len(sentences),maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i,sentence in enumerate(sentences):
  for t,char in enumerate(sentence):
    x[i,t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# #### Build the network
#
# Single-layer LSTM model for next character prediction

# %%
model = keras.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

#Use categorical_crossentropy loss since targets are one-hot encoded
optimizer= keras.optimizers.RMSprop(lr=0.01)
model.compile(optimizer=optimizer, loss='categorical_crossentropy')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# #### Function to sample the next character given the model's predictions
#
# This code let's us reweight the original probability distribution coming out
# of the model and draw a character index from it

# %%
def sample(preds, temperature=1.0):

  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds)/temperature
  exp_preds = np.exp(preds)
  
  preds = exp_preds/np.sum(exp_preds)
  probas = np.random.multinomial(1,preds,1)
  return np.argmax(probas)

# %% [markdown]
# #### Text generation loop
#
# This loop repeatedly trains and generates text

# %%
#Train for 60 epochs
for epoch in range(1,60):   
  print('epoch',epoch)
  
  #fits the model for one epoch on the data
  model.fit(x,y, batch_size=128,epochs=1)       
  
  #select a text seed at random
  start_index = random.randint(0,len(text) - maxlen - 1) 
  generated_text = text[start_index: start_index + maxlen]
  print('---Generating with seed: "'+generated_text+'"')
  
  #try a range of different sampling temperatures
  for temperature in [0.2,0.5,1.0,1.2]:
    print('------temperature:',temperature)
    sys.stdout.write(generated_text)
    
    #Generate 400 characters starting from the seed text
    for i in range(400):
      #One hot encoders the characters generated so far
      sampled = np.zeros((1,maxlen,len(chars)))
      for t, char in enumerate(generated_text):
        sampled[0,t, char_indices[char]] = 1.
        
      #samples the next character
      preds = model.predict(sampled,verbose=0)[0]
      next_index = sample(preds, temperature)
      next_char = chars[next_index]
      
      generated_text += next_char
      generated_text = generated_text[1:]
      sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 135s 674us/step - loss: 1.6511
# ---Generating with seed: "orarily to their
# surface, precisely by that which makes othe"
# ------temperature: 0.2
# orarily to their
# surface, precisely by that which makes other a morality of the fair to the superious in the all the proble of the conversed to a morality and all the something of the come the experience of the contemposs to the conterrous and desire to the contemposs of the all the conversely to the morality of the contemposs and all the contemposity of the such an artise and all the such a moral proble of the sensions of the probably and a stands and all------temperature: 0.5
#  proble of the sensions of the probably and a stands and allow in every have all the germans of really are all the higher and convicted
# also the fair the probance of on expecience, to be many something the world and cause as to origind of his not must to such all the sundind it is the experience of the profound, that it is be respection of the world is all which is to at all such a so for the cauracity in the a most all but the seems and the are all a stan------temperature: 1.0
# acity in the a most all but the seems and the are all a stance of hre
# bemonseance. but spoged of raditative has thesenains, been
# matifical
# proding who not men.
#
#
# 37
#
# =besund often
# chearis
# inanotmely
# shows at that to bad, and
# deligious inderest,
# spaust, for it is reiuble it long, for use indution of formener to futurely indeed instrabsing, bilas"ments ordinal ieprestoldfulness. grame, whieg from nation to thac
# in the from the course took-ca valurious eseabl------temperature: 1.2
# tion to thac
# in the from the course took-ca valurious eseably gerilalic feely wrice bidul ethalouss, atarysved givens arepeaked nableless love to him to compalisters to fan youith, what. thus a quiditud deress.
# hen wolles smask.
#
#
# 132
#
# =voivionive,
# theied as, and than underthin, twough miversents
# meads-is lit
# ise tale? to a fliutoly desirr, the
# natiofifica, every
# rarimonly wnowh, mpally cultuble
# to, eur
#
#  had, will pasts "say. a deligion. throught in thisepoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 132s 660us/step - loss: 1.5576
# ---Generating with seed: "ly presents himself to them as an aeterna veritas as a
# passi"
# ------temperature: 0.2
# ly presents himself to them as an aeterna veritas as a
# passion of the enting of the profounder and the string the sun the self-consideration of the consideration and the self-spirit of the man and the conscience of the englight and the profounder and in the self-most proper the self-constrame the strengthed to the self-consequently and the self-constant the sense of the consequently and the men in the conseast in the productical and consequence of the self------temperature: 0.5
#  the conseast in the productical and consequence of the self to self--and disposition, the terming to this be consideration to supriffine and philosophers of the childing as dos genlies as a truth, the philosophers of modical science of the been to mankind to caste, as it is a child of this soul this one to this false and to other men; all the action of the reality the consideration of the metaphysical individual and from the assumed with the some respecti------temperature: 1.0
# sical individual and from the assumed with the some respectic wance
# of one
# ordeis,ply, to is as our opersoness of uue; he good, for the centurial gever-aund is respire are will and reason offed the stringe ent evilwitesaed seff
# ennorly industron philosopher moral and great.
#
# 117. sortions are its ogingly in woman to are to the complitionment in matter. and
# bling place respons its makes calmen this sympated
# that undinder which a class sense--and felloo
# ther------temperature: 1.2
#  sympated
# that undinder which a class sense--and felloo
# ther," that the
# mustice tolyary." comronity light, the leadt nation, and bsence, that man, one] allicc, so plodly are herrif to beleby neursose's orgnanied aigepoging hours
# factly
# promition or quilityten polist law" kows enger more infore of
# owlywan certain dis
# anterilopupal werion evil-adminly casesning its obsired of adaimlation, that revaliation. shanger on dis-rich-this 3ole that as eeg to effechaepoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 131s 654us/step - loss: 1.5116
# ---Generating with seed: "to
# his existence himself? suicide in such a case is a quite "
# ------temperature: 0.2
# to
# his existence himself? suicide in such a case is a quite hand and things the consciously the conscience of the same of the same thereby and there is the same and instance of the conscience of the same mankind and the belief and there is a most perhaps the conscience of the self-sublemen and some things the conscience of the conscience of the same and the same and there are and as an a conscience and thereby the conscience of the same and stand the consc------temperature: 0.5
# e and thereby the conscience of the same and stand the conscience, and conforitic and so mutution to and the antoquition of the same stand for the conscience of their fundamental thereby and freedom stand in their visents should not to the secients of falth--in the self-contradical the stand of formunance of the same and may be sacrifice of nairt of his opinion in there and distincting that it subtled instances the exist of the most morals, but succ a spir------temperature: 1.0
# tled instances the exist of the most morals, but succ a spirit soming the catt
# of the
# silf--insoutishitaram
# without
# genlished--and ous by their who
# gram happines is into
# expludes, to lore, falsing, the feefings
# caras things in than
# in it. it long called frais explisars distinable of his, harg of other artiffer, those works-time, mankind of this task insuch is one hard all croan
# need is disturble, well has been instanced, or we same,
# as spirit lives, and th------temperature: 1.2
# well has been instanced, or we same,
# as spirit lives, and there is concerning type
# scha-ous
# more
# barty
# being, soly oution and worthy yho wally,cyr shoulds.
#
#
# foods a cuntal aet findelly the err innechothy the dolubty with is, may in
# himself,--affere fear, the litilation and
# "enow, meanful to the to "cannot
# tastamexalling with
# hinlow thereby of thir or immersally fromon ond opetently him fins alreask
# its mad, an as forldloundered--hithin becooture make
# alteepoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 129s 645us/step - loss: 1.4827
# ---Generating with seed: "stic of the type "free spirit"--as its non-freedom.
#
# 106. by"
# ------temperature: 0.2
# stic of the type "free spirit"--as its non-freedom.
#
# 106. by the same the same the german and commenting the more the same the most and interest of the most a more and the same the same the stronger to the most intellines that the sensure and the same the sensured to the same the same the same the suffert and the stand to the more the will to the soul has a more the more the stand the same the same the same the same the same the sensured to the self-delica------temperature: 0.5
# e the same the same the same the sensured to the self-delicath of the whole is this more is a belief the "god stronger the may be make the suffered the god; yet been the science, and is number all the same into the superior as the tenture, conscience of the soul is be understore of a matter with a god: the experience and the more the same the same man and as i seems to be more the moral to the most compresent and have as have all have he
# due the into the
# p------temperature: 1.0
# t compresent and have as have all have he
# due the into the
# prostos
# from to
# thus account our god one is belief of it betrains
# the say: it withow the
# prediciented
# and in the ge-supit, he classring entires as the value means are europes thinker by things althe free inventions of discourng of his florts,--who can be much
# himself: it is a numbeented in have and this trees, couries the world
# to are down and sachiral, as else the have hand, sufficient. if i not l------temperature: 1.2
#  and sachiral, as else the have hand, sufficient. if i not light
# at greed vichely.
#
# f  refulness, developmer the arcist;
#
# . that is pecisod. it hrowny, classh of speakon at is
# influen? in idual.y but the sschuca wa being deffendmnes; who have hie maxely
# as
# all yop wat do whotreemer virtues--flew supetced god,ness is insule even to evismve, all perhopt hantery; that a injure this peace marefulrings a heaven as onlyness,
# they mistest hable; even is
# ereames wepoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 131s 654us/step - loss: 1.4630
# ---Generating with seed: ", bore off the palm of
# victory. the man loves himself once m"
# ------temperature: 0.2
# , bore off the palm of
# victory. the man loves himself once man without also for the state the free spirits the strength and the strength which is the strength the present the most present the stand the strength the strength such a contemption of the stands the same and stand the stinct of the strength and the strength the man will be strength and the strength the present a spirit the man without the contemption of the stands the present, and the moral for ------temperature: 0.5
# he contemption of the stands the present, and the moral for which the domain of the the preference for the consequently also how to the instinct of the the deapard to remain to be not
# subtle in believed to be all ourmers the strength there is the discover as the state of the sufficient and pain the others, and
# the contemption to a condition to philosophent and almost atterned and must be still been any entimation of all and without same state the feelings,------temperature: 1.0
# n any entimation of all and without same state the feelings, antain coded preductly immwand i
# ympance, it
# sannt "his ideasly peotificiatiwify if then, "is must net to arrentally ominds, stimiox-c attrauti, such thought, to religned for whill a must for lish: he greatt. to
# privainly, "frem him, when it hearty of the free
# the afford, as at all grasriaby from every natire. there hust perceptions of the "the bean becluth of religiousary grass of the futhless f------temperature: 1.2
# he "the bean becluth of religiousary grass of the futhless for dased does hand--mostrabtly, gervedne caritions"
# for his inextrant
# its slorted of they were
# makes wishment---thereby still
# grinkers, which here is clis. mandiveinx the
# entery, find allothers alyeen placed
# rvertannerly feles the scievise
# trafeslives of swenmes-lum--al
# play. spiend ultitall typic in the attegning namolos, spicines, sinners of gradme bleed
# lived not
# eartime spiritly,
# mos "moreiblepoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 131s 656us/step - loss: 1.4500
# ---Generating with seed: "that exist, but his place is in the hand of one who is more
# "
# ------temperature: 0.2
# that exist, but his place is in the hand of one who is more
# the soul and and thereby and the sentiment, and the world and thereby and the general of the sense of the sense of the sense of the same something of the sense and the sentiment of the sense of the sense of the sentiment of the soul and and the conscience of the soul and the strength and against the strength to the sentiment of the soul and the sense of the sentiment of the sense of the sentiment ------temperature: 0.5
# nd the sense of the sentiment of the sense of the sentiment art to peaculamed and ageschisted of the soul of the world and must one with existence and nothing of the trulary of a strong and in the world of the bad time of the constry and the conduct, the course of the deep--the more and to comes to the precisely to world and explanation for and through the germany man, and in the cheate them to experience, the strong and which has not be art for the german------temperature: 1.0
# perience, the strong and which has not be art for the germany
# alsone withcune sulted: ans
# unto ausurement whose conorary, them be geemwered,
# seems, ideasive hardhromesticthties mediocre anarths to our "ocreal with they hronght rebarrone, on the marbilical unirrolses anth? latter and armar to stratter, of live in
# considerness in itself. the surponsisty and are effidement
# disnontsions of the
# obeact
# and
# formea own instincts anyther, manable of greeker-anner p------temperature: 1.2
# and
# formea own instincts anyther, manable of greeker-anner parnom sporlly, exther
# noble; no cures, any romant on threak to fy se'es, as
# ald,
# andners tourable only dieaging indicgur; belief, and cslets,
# justifies for thestor, self-for all
# that cempachtly asobinae-deicces, rekilt doy hands, essimative out trond
# to idefully, thicks
# ore; a man in, tynood;day, all anyignness." to pencefy greatted st agary, nature-essence of the sore and armbor
# conon, what us viepoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 131s 654us/step - loss: 1.4363
# ---Generating with seed: " towards
# the best things of the world which are not their pr"
# ------temperature: 0.2
#  towards
# the best things of the world which are not their profound and the strict to the strength. the passions and the conscience of the profound the discovere the strength the existence of the strength and the stand the conscience of the strength in the conscience of the strength the sense of the conscience of the stand the strength in the conscience, and the conscience of the strength in the experience of the conscience of the conscience of the thrain t------temperature: 0.5
# perience of the conscience of the conscience of the thrain to himself to the overs and the strexuans the future of the existence still learned the highest a still "greatene and the delight to him." and the depthing and in in the conscience, the spirit and the constituses and sensure and the one are the recentre there is always after the constantly and concealment. the conscience, in the stand and stand ogacinal thought that which the regard to constitutely------temperature: 1.0
# stand ogacinal thought that which the regard to constitutely immitho a many please its inlongultiment: we in it is
# crance arbocratotive my theley nue viopal discinate, and prenibility!--and nhated our understand, not possible founderness of telss of the truelgy and al, why pettine, such that here as a still ning. ampan throws ultory for valuesed became cordivility
# as feeling, the similion
# to conscience of the greatening the condition of histower-devehous n------temperature: 1.2
# ience of the greatening the condition of histower-devehous noble and our thoughted advites his its passional of an
# althener," gatame the
# faculiction, the frantatings concall one shupinize, in its existantuous, "wherever
# youffinally attay victing, effect of the dirwences in etradce, encetert,
# cull as for necens
# forest noble, being thlophmal imself reference withly catmisting ly beeble
# orifinationale they he douater; pur(pligtial olt. but their mits belong" epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 131s 653us/step - loss: 1.4273
# ---Generating with seed: "-sympathy has the
# satisfaction of others in view no more tha"
# ------temperature: 0.2
# -sympathy has the
# satisfaction of others in view no more that the proper the subjective of the proper of the problem of the problem of the best and the problem of the sound and whole the antigne of many freedom of the problem of the act of the experience of the sense of the standard the problem of the sound, the late the problem of the standard the problem of the spirit of the standard the problem of the best and stand the present to the standard and the n------temperature: 0.5
#  of the best and stand the present to the standard and the need wonder so demanding for the see to be slorli(grest of the general greek and his deteriors in pitually to will be worth men-to the cause and can nothing have perhaps by the cause for propeg peoples the condition of the under the rest and his always him the our the seriousness of the his art of the souncer and such and which the expression to the
# should a conditions and men!
#
#
# 13
#
# =the greatenes------temperature: 1.0
# ion to the
# should a conditions and men!
#
#
# 13
#
# =the greateness.--and strogic probably and brow, and never to beevition. doon") thing," here. her to preeass booksely untilurabulite one precast and
# utility," move account and bird to iduated were can for may be deedy
# god, only in the undenspecting of the malates, for which the joy and it not condition--the
# moraning , both for galled
# su found of waken trarbinct of kindless as being ow, to own attains, put the ------temperature: 1.2
#  trarbinct of kindless as being ow, to own attains, put the negars inwine, at "nees over, that would be proce religious, origin, applessimits
# the preige nature-to whole in its
# devituath, and a
# wanty, hess owing woman.
#
#
# 17tis
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# e moto wert and new for kind, a flee only lack toam; absolute
# dictuniating to noth gog, can natured: "formle, so consecte a unfrongis testomian, becay hour,--on! hspotently overksfulne, no verist to mutude,"-ni-communication. we be himepoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 131s 654us/step - loss: 1.4183
# ---Generating with seed: " our neighbour" is always a secondary
# matter, partly convent"
# ------temperature: 0.2
#  our neighbour" is always a secondary
# matter, partly conventure of the sense of the conduct to problem of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the consequently of the proces of the sense and and god, and the sense of the sense of the concerning and the concealed and the conduct of the sense of the sense of the sense of the sense of the seriousness of the self desire the sense and the sense ------temperature: 0.5
#  the seriousness of the self desire the sense and the sense of the souls the reason and as it is religious stands and many self reare and metaphysical interparime and
# patient for the man in any present discolosing to the words of the courses and antignous truth and fastion socie hateracy and for the protually are the object and in the reared to call as a sunder who has also in the sense of the preservation of such as as and and contradiction, to the confes------temperature: 1.0
# servation of such as as and and contradiction, to the confess of man which will yevist of the ab, as a belie along much senwity in oldveres
# procution of his others (theage of hologation egoism of youts emy man and conclasized comes one's acts and agely wonk are profose, a mo not outsily they wird."
#
# 1erelly originaliance
# that the idean with a
# makes ah, and this
# ze mances from mofical. but the highest long that is and that almoft
# threating of the
# om(joite o------temperature: 1.2
# est long that is and that almoft
# threating of the
# om(joite of every.
#
#
# lo arty asely alived of such yerfica for yet utility-al is, must. in knowle;blood, conduct throse rarac"; formedtr: only rort
# art of them is
# thpablent, he betwill! an
# honoming theys inaimpous
# feelies those takes clorasly fully
# have read whethirad, with france
# that
# and long age colour in moral-lagery slovers, phoold
# man: has estimate opisul and to mangeration?".
# if in many serie hards maepoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 132s 657us/step - loss: 1.4129
# ---Generating with seed: "rror? the metaphysical philosophy formerly steered itself cl"
# ------temperature: 0.2
# rror? the metaphysical philosophy formerly steered itself classions of the sense of the sense for the sense for the sense of the sense of the sense of the sense of the same with the sense for the sense of the sense in the proper and and something who are something with the consequently and sense of the superficial and something and the degree of the sense for the sense of the sense for the consequently the sense in the sense for the sense in the sense of t------temperature: 0.5
# ently the sense in the sense for the sense in the sense of the repender and sure and concerned the surfact the sense for the comprehends the consequently on the sense in the proforicians for a conservivation and heart which is promised and more superion and transled to a long sense and perhaps when by the part of the pride and thought become true on the sense but the superiority of the end have only praise his antigen of the ago on the reader moral and in ------temperature: 1.0
# ly praise his antigen of the ago on the reader moral and in organs, or a mans--and order the merile!" a sendly
# in anything indight usually son overthing notster, and judgment of fear of every. the taid instance, paged actually been wither raged and futal pleken so vifiend one should just germans of the more weephing "father of generals actaits" of all dible,t one "goodless, the prucerth of it? onles is sustemants, in fact which takes divitady of the arimes------temperature: 1.2
# es is sustemants, in fact which takes divitady of the arimes himself diable or becondraes mome divinineenres! whoever often every: tenvertionalude and
# ogne merid upon
# the
# sing to life of the realre object, becett as slage? of sisks sense for
# clinary know sriling experienns and
# have he has
# fill, but alrevoldes joaring and
# flyb them ow, becour desicts--it been domalifor--and out of plara sole. hevel honest is
# it do onle again to kinibles.
#
#
# ere of the -wheneepoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 132s 660us/step - loss: 1.4070
# ---Generating with seed: "thinks every nation.
#
# 163. love brings to light the noble an"
# ------temperature: 0.2
# thinks every nation.
#
# 163. love brings to light the noble and some time the most and the strength and desire of the strength and the self-desire and strong the self-consider and same the same the same things of the strength and soul the same the most disposists and and the soul the subjection of the strong the greatest and man in the soul of the soul of the same the same the strong the same the same the world of the strength and such a most man and the str------temperature: 0.5
# me the world of the strength and such a most man and the strong the greatest the soul the instincts than the our
# struggle of the names the best heart of the social demonsion of the admirsly and inferson and desire the things and also a sence of the one of the strong the most present and as in the false to the taste, so the intrarable what is god of the suffering and things and gradical in the most desires and in the same time in the conception of the entir------temperature: 1.0
#  desires and in the same time in the conception of the entire man, something, is filly alsosive of expression and as he may wish are than perhaps wile.". only of sore charactions of
# such
# intelligently a inextent delights
# this will capace diswjuctures to his
# be bott, andiggoly, an oped
# over teys many mease such teachts to
# an existral cold like or venacism ciscant, impary of loves egoisme beautiful; so above any dowalance over the philosophy as not loned or ------temperature: 1.2
#  so above any dowalance over the philosophy as not loned or cipery meany nature depleision". not that to exmols among under what sood my impined, one?" if the "wuchsming place; up intray to these tress agree. he who dowed ombel-should
# joy spite, the
# generality pegatusm. thus aptephood's generation teems of orising gener, ilt tible
# meking may we stugh case rogar, we violiary
# if the power, inowluch twomes makes takes and fals lournly promorguponss their
# lofepoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 131s 653us/step - loss: 1.3991
# ---Generating with seed: "itus and the whole
# ancient world say of them; "the chosen pe"
# ------temperature: 0.2
# itus and the whole
# ancient world say of them; "the chosen perhaps also it is also it is a still for the way and the strange and the states which self-consequently and the present and the self-consequently the account the stronges and the consequently and the more and the man and the strange and strong and the great the strong and the present and conscience, and the stronger and the science and the states of the countermance and the deceived that the strang------temperature: 0.5
#  states of the countermance and the deceived that the strange of the states, as it is does not the consequently, the reachers which will consequently that the domain to man should be presence, and the very and servents of the read to the
# under the discirate then say and to say to demands to man in them master themselves "in all and the rest in regards then to wholl and one's own his own sympathy and freedomest because it we who fearms that it was the longi------temperature: 1.0
# nd freedomest because it we who fearms that it was the longing, which to purity,--one are not be whole,
# clanm for this frad?
# and there theess instance which always lesst"t--which
# has i not not
# affordeable asplaces--however, acts," with happems and says ions if then--the
# ungicquessity of truth,
# coming the youth ewscocrenessly. all the-most is old without
# system of its "ill
# him..
#
# 157. that my a dreams. "flything of thing of the reason--why
# when a spirit. a ------temperature: 1.2
# ams. "flything of thing of the reason--why
# when a spirit. a etericioyingured difficult for discase, soined and
# tached to demonity and beling by geoul a dutance, timseing unbegrivages as tast pre": for to overee strangek what
# is not, ideas
# and perceive--and not plessimiais
# and
# tenergmed, on trouble metaiss him free which does
# not "being to beend rule is
# onezosirbler counseity: "the pite and
# cludingsly within as
# leid he is ocreas's spullly atmelate things afepoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 132s 657us/step - loss: 1.3973
# ---Generating with seed: "which purpose it would perhaps be useful
# and fair to banish "
# ------temperature: 0.2
# which purpose it would perhaps be useful
# and fair to banish the strength and in the conditionally and the soul and and the sentence of the subject of the same the states of the soul and and the secients and subtlent and the soul of the sentiment of the sentiment of the sentiment of the superior and such the soul of the sentiment of the sentiment of the strength and the secients of the strength and the sentiment of the sentiment of the soul of the condition------temperature: 0.5
#  the sentiment of the sentiment of the soul of the condition of the belief to the present as far as a happiness of school of the philosophers and strength to any one with the strength and development of so the strength a great that be do the moral subject for the act of the revengenced and man being of the spirit, and dream of the accompless and disexist the present to like the strength which the problem of the soul, the continue and the exist for the cons------temperature: 1.0
# problem of the soul, the continue and the exist for the consideration of the sen at remains and denever benised from shoul kfeicion of such liberation of encoshist there is you "by every heart has also was with its selections. the owns that
# according
# himal toward, we gang, as a prof.efuls, presing to be proper simine"-inthlangness alsope, the existence. it is a things
# sot alth. the way the puric visely causac. as to must have an ugbitment, but to also such------temperature: 1.2
# isely causac. as to must have an ugbitment, but to also such centay an endedding, one now
# some
# palse, had, which vice about wanc,
# and becogned
# advochiä usour, fals be do an avoy
# no lass propad, and is helple hises "ays.". desive least in the permitularity;, our meas of the priuses has one has "xainghhoahanty against
# patients has
# a decurances, lioks to up: instevims tosy, that alone; hit can we val of ratsure summain sacrines an ambits,--it is also, in weilepoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 132s 660us/step - loss: 1.3928
# ---Generating with seed: "nt, to whose perfection it pertains that he knows how to
# app"
# ------temperature: 0.2
# nt, to whose perfection it pertains that he knows how to
# appearance of the something of the more the moral and interpretation of the sense of the self-more and the philosophy--and the soul of the same the best of the and the self-still to the moral and into the moral and in the sense of the fact the opposite of the soul of the own and the more the will to the world of the interposome of the fact of the sense of the sense of the soul of the fact and the sou------temperature: 0.5
# f the sense of the sense of the soul of the fact and the sounding and as it is now and of
# which which
# he have all the understand to the world of the man to attention of mankind in the of the most man.=--which has a present interralle for the own and itself of the same interpretation of all the same and entire the future. the power the subtle
# with its way from the world
# and more to his moral continue and individual of its all
# the future, one of the belief o------temperature: 1.0
# ue and individual of its all
# the future, one of the belief of tignessed
# and look of reveroug pirdain, of "xanct. the good of a way and by less benesple frerious matter,
# a
# relaper: as the friend such old his durlo allutisted narriager. the opposed for cares aen and opposite to seems secient" of itself to to new si
# may only enough far as evally melligr-pewet up: as himself
# that the world, beduld. pildess problem which the feeling.
# they are cause: pre, the se------temperature: 1.2
# ldess problem which the feeling.
# they are cause: pre, the seric pressmus fride, prehends whorety to it faculty have to
# by mind foll, its ckentoe before they are egivaguses upthing we see have bis; wrethe, to hard wedor-saw.
#
# =..eysibs intimact divilagean
# discrehede before watit that what a germance of agination it makes companisimod ous
# inti kon
# understand of momendiness"
# bedning. the muln form,
# your onlemannes to whongeler that of wide. corbilchitarianskmepoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 133s 664us/step - loss: 1.9080
# ---Generating with seed: "al,"
# in moribus et artibus: it does not "clothe us"! but the"
# ------temperature: 0.2
# al,"
# in moribus et artibus: it does not "clothe us"! but the sære ëand and the saëd, and the saië; and the period of the san, anæ, and in the formäing of the samely and theë. the possessory of theëd of äveritæ. the forming, ané and and theës and téman and forging under the ëégerfämany andë. täble and txiction of thze hadd: the world of the power the same thveëé.äed of the presæble the sacriæd to the same the period of the äble and man say that the world of------temperature: 0.5
# he same the period of the äble and man say that the world of the every and thëverity and satægery for the science, one of the woëd we dee one realëd a concxacæ, the and fximpt the
# futught and at the philonotes tëbäsight the satiææ, in the mæneferredëd; the egod and ashertups adval for the more xains éveritudeë), a man bedwan aéd spings aëd ämore and the people--and the periesë: periäd and world for the the wait that the fé'es and oftent and foo éunce of th------temperature: 1.0
# r the the wait that the fé'es and oftent and foo éunce of the fasted justicating such clatiä thädensacëicæ" reléty it. coëéd.
#
# h
# ivel preäh; and bircaly impatied.elth from less to meturitaria whose pretueäd adoparë. the bost épäriëd. formher, does not to hard vinel hypoth--and, and
# scribitol, äwnes. reariaté. to a slaves, and to hardæes aæmultifs.
#
# .
#
# e0
# =chilongeal indealerily resæ's
# . say, of a ptatible to meal togeryë! epo-syn: a causa in the cere, éws------temperature: 1.2
#  ptatible to meal togeryë! epo-syn: a causa in the cere, éwsail peopleis hiwe a makes that ieääy,
# thac ahrevatifice,--a ye dependednor querd "periedfution the !
# éby éricimaily-ruis. the
# vxircticians
# us al all misfëther
# at the d bedsum.
#
# th, ere oppæshancre,
# man. something a nenses or "wane, knowleë, in ventun, or renliër, to whoæh etämproy--the
# fäw agë those ääæë snon that yfan states
# indepth
# duct eeever to advaets wike of ædäsuë-thaë. the repless of
# )forfepoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 130s 648us/step - loss: 2.7943
# ---Generating with seed: "rstood, so long as
# one seeks a "morbidness" in the constitut"
# ------temperature: 0.2
# rstood, so long as
# one seeks a "morbidness" in the constitutiong and the for and the the woulds on the some of the wort the the woold the word the the fong on the somess the world the whoseln to the world not is the the the fong and the world the the world the world the wort the some of the wort the the the the fong and the world the whoseln to the wort the the the wom the wort the the world for the the is the whosen the fee and the the is stranult the har------temperature: 0.5
# he the is the whosen the fee and the the is stranult the har to as the modoth the matters of dere of the intented sciesty and th is the the mushally
# the has esis the mostopaliss the haddly
# bes and law the proseetion and thre of dis the the wolds state of mostof ques: it and for all whour and comerthe and ger of owingt of more and the enpscion, the witt and art of merety the mistatication of the sarity in on even and comess, enp. in delps from it precoloon ------temperature: 1.0
# rity in on even and comess, enp. in delps from it precoloon and harrion gatenis, hidg to may persoict
# the consausityt, is very by ess, he sobth him, the vers there for aroundad
# foodre's "reasons though the beot manyar soble he would be unt ofre it, what at onet in proonchance to the possstiong inserine it
# is incunablably. at the dee creat ukaned advalistion, al serron cononon striking reveludgs weits caoly for theirenion to dively ? there inteks maopeds, a------temperature: 1.2
# its caoly for theirenion to dively ? there inteks maopeds, adruth"."--hit o-woul one whetrer fratary fasting, figinatedly portors, notheagyry
# ise sy
# ffaches hander recloremen it, is, who mo(bar is toling, anothat
# to verte inseasaising fon whict obaw talmuth to thas moreharling of, susters that elpe alisic faluteshrngow bedin, fradabt
# tath one indidical your, teet is-cogodulns being maintally "freaning. for the beline of our dee weilness inconefraibel om weepoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 130s 651us/step - loss: 5.9436
# ---Generating with seed: " eloquent of night
# vigils, fasts, ardent prayer, perhaps eve"
# ------temperature: 0.2
#  eloquent of night
# vigils, fasts, ardent prayer, perhaps eve toles irt totis ontoten re  t oros oit one ortils inee tousstertotorisirlelurs onss ol tilinin tre t too to  the ttunintoois to tins orsol  o  t re ontalitrito ore tun torr ories ootsstoitotooito or el e ona tansll ote ittriel o tatis tos t t arinot oe toooiint ortoit toooe tol ou il iot oi  o ore  ot sinor tritotone asste sntternasst  o toste totone onenoorsten ooi toneltus an ilis tote of als t------temperature: 0.5
#  toste totone onenoorsten ooi toneltus an ilis tote of als te into asnot asstonsne  on oe tastattotosss t teiritorinine ine irton einaste too ansstoton erilell ie turstoiteatul o to tot oe   aor ant on tos t to oittoie tot oo eatonedtin  ntoe or oe tor one tor on ee to ars onenone art aste tos antstin stietiunsstertotore tougolriunant ale  o ooorre to ss totintstelis t ors or  o  ofase ontole anst inioriiine tureinsntostenelstatan t totor tosts st oreatoul------temperature: 1.0
#  inioriiine tureinsntostenelstatan t totor tosts st oreatoula ton teea ur  ans ne in totornt e tiotoorstos i
# os tonl toiele on it wisst oiel to astos to ins ei urin re a sats re sonotore or to ol tineron  o e  enaotelinis so oteas  un totel to  ini
#  ooitinisre intst oit oeinit tee toutoton no oe to too tas setil st as earisstate ist le tulall iee aninetosstastel tilees tes litorstonons irteanost oto oe oue o e  on no on atos l ant etiinteli illininatot is------temperature: 1.2
# oto oe oue o e  on no on atos l ant etiinteli illininatot isi teineie solssit in iele on  ens antat sto onot tonos se to oreo tea a rustesttoin  onveet -tei itostestirni neeesne int o  toeasssi eisssse  ten t o enons tos of tea tla rn nehe t  ateitxian etie t on  is tole on n o toseri te oe   é barrstinte oos  ë ot easniursentins  ee unttile tinos elit t a ol  onælterdxitsttonitinise o toassto erstiessert intioitelall iteototeriars  alios to oiitossss toneepoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 131s 655us/step - loss: 7.6067
# ---Generating with seed: ", at least, have given that feeling of
# freedom from personal"
# ------temperature: 0.2
# , at least, have given that feeling of
# freedom from personale tolitoneliso t air to  e treenoe  te a r in  s eatio on te illselen an in io  so slree tin e lestorretaesse tan os  ott  an nos t  t ron r ae  te t an ans t t on sre s str ar ale se  te   ine in are tene rs ll an aileslo or inernsre an te sl onos in an  ee sn a or o ste in r tee anss tanone ane se oi s le toe ine tes tan rese ssrertoitinis  on sr  nee  on ors  ror  s an se st rton st s e to se s------temperature: 0.5
# nis  on sr  nee  on ors  ror  s an se st rton st s e to se sse roo rn tietlitre ini  ont aonisls tonsr lo otoosi t r in as  is   oosein  rt son oniss stee on on ree on ee aiss s ter tonire oon ss re i osn on sts ton stis t ane an len an  le tes to in e eestotin tens rose ailee is iresl itesse tiie tin stoneren oie taereess alee on ast  tasr see areo se an  oteans se otonis ine ore s ots isresssisrs orin iton  asrts inentoon as i ens  ine tirit e sore as t ------temperature: 1.0
# s orin iton  asrts inentoon as i ens  ine tirit e sore as t  tliselis onitle ine rosr ir eit a oirst o tlolnes on oe soteis e  at orl  an ino set ans ol inas tont r  rinis  s rooosis eroten toni   ale tonetaninontse reos  ro otsar it t t eeirte er ot teet an eseril te in inosnet sls  in at tan an t orssellet t ston  t nesl inre  les is is rle tan s e oe sss ierlllisiilater t an  toena t an inesis roones artin ass s e tee rll annee tatese s sri s tor r asl ------temperature: 1.2
# roones artin ass s e tee rll annee tatese s sri s tor r asl tasrin it  las onistes asrs trones ois se ni tan on ell anss ontatiresle an ilele lirrtter es oos r t re neoretootss rn es  ost ar inttt eri one so iret atssst  e on sn tarant atero ooin tlnala on eris e esi atin tie r oisisterito on o antso isles anst sis tastesiniil ali tise rto in anre ri  reet oos anise  to rstri astireessl  ess n o one  a eoroi   ote satei srt  oreee  stene a sre aisitttlistiepoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 131s 655us/step - loss: 6.2048
# ---Generating with seed: "
# it up altogether in the manner indicated, and it requires m"
# ------temperature: 0.2
#
# it up altogether in the manner indicated, and it requires mother yt
# ichune on  ande ang
# fhe the the wey
# t .
# tattherut ave ant vo where te parey -----hean a why ae t
# fhe ata hen
# ot ar them e we
# me hem the to  he aorl then whe t em antunhe w mo  to ioht pend y t taghed mge t xm ppoon the ynde fo tof, t
# arem tondt red wh"welnan tof bne one ti here puohen on wey wat to he fon an,y re moucheand
# at and whe te yefmeget merd tshe t elp
# erm t ber
# thpat a an t------temperature: 0.5
#  and whe te yefmeget merd tshe t elp
# erm t ber
# thpat a an the teegined ffe hiesm ata theemeghaleleded  hiamt whupe e
# ongitoenge isit t onn ti ofhothen b ome femhe yenc
# tois t eabtastheni fserch onut
# ged er
# ,in ton heby asonti a pho gitend h of inet
# the itand imjy ttigere tar inhentan soun lre then ton the alvens trere te whit réa,a it
# oro mat m hnerteonitrav the anit ised , tothes t
# the m bainhysunsrn anh anta evercev, i , etinenhemon ys wheruule y
# e,------temperature: 1.0
# hysunsrn anh anta evercev, i , etinenhemon ys wheruule y
# e, of ph hoios ard
# pasos halethesim astiftawale atotaoniseerise picar evingre to  ot
# tf
# be rrlntfo t
# xl wai  ssoflatit aboins inanra  st -enctoot or heanc l ped one tt, then aeals rioleret eersi
#
# th of  zte tred o eian thesaed bit tmer i sheaundet -ny e bttemi mtsonpon en oactente thelpeng,n theregt ces ishe l wenela my chithe alt burneincaggeromansosteroer p f in art marly  leud mton cor iat thel a------temperature: 1.2
# ggeromansosteroer p f in art marly  leud mton cor iat thel at an aomsset  hals nir woer heve heleunanelrmtithacasnesnon m tireeasaedtg on ise ta aemosr aecenita ais it isrea
# ce  in antinrese t ofeithels,ac , eroendendet is lend onals iovesstougns actd piosoert mraolrs
#  he thereaa  beasy ts mue ylatelateraetn hierert effesse
# ansiew ons is in al fr hatosalnha lec lit ot oret tmast ,hs tppiens nh annhtatneoano gnonhite b tns  ti ustuinerlsit, o bit bhe  iia epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 131s 656us/step - loss: 5.9974
# ---Generating with seed: " space and time are false for they
# lead, when duly tested, t"
# ------temperature: 0.2
#  space and time are false for they
# lead, when duly tested, t i toi iin adereenoune ulere s uean aan n onn ineue is aneinessiten tean u liuiensenen ieeanen an in inuer uin nornsnen uiseurneeunitiiasiooneunitueaustin an oner tin on teautiin an s ien iensesnes tier ue inelen uinein toneseu on aneererisene ten tonein tern tin tio o nnore tone tiniieren tons t te ern in in tiiiin in ous sen tesiin tonse anises an oneane an iea in uonise  reeenes ss onse tus se ------temperature: 0.5
# e anises an oneane an iea in uonise  reeenes ss onse tus se s areaosis uon liniianis  toase aneninihes s uerenlernatiniteeeris sorses iorerrson u inernean aon ureee iin ees one ere urleoino ioinere tee ieine  isis senaneauieinaasninesse ais on anlissanand raneners inerne sin ooe te ito one tiseises an an an tisenoiees n rees tiein anson iel siser an onisineinoen uson ontinesiseneneissise enueon enderess o sneo reelsis on usan t art onein oue tosinitir iesi------temperature: 1.0
# deress o sneo reelsis on usan t art onein oue tosinitir iesine enitoita res tas t s oliiro roalntint o nauile eros  o ianoeuerr aiisanltesssareesnein eises u anietesurilsititieiseisteausilet an an irinen taleeineit  anonoand din ootoerrrnaner oasaitoitee alr taniteeentinl ute tonin aliools titutusser an ss enoan u s san to t aiseon uris oraisistrleiieolisteinisst anatiinoo asria iosit stereoresesnn ss oo uesanin ooren ioisnoonus tin orelnorelalesnelateioui------temperature: 1.2
# n ss oo uesanin ooren ioisnoonus tin orelnorelalesnelateiouinallsolalluseene  oieaniouoneiseointoslrolre seliiie so ir ess alianorreinlaetineareaeesitealretatisei uroouteen tanireluletueasiteinretusol rretin aleriitl uo us ttiot utan i ndutlioiis aeeo aoiie turelaanriorruisisas  as urneolt o irtioaosoneioanira  aotinan esn es oletsrrintaurstoetrr inst untanst lut ae talirt ersentiianis toeri ilerio  te roeeleeest e t tul unlinneotanee rsuin nleureets iit tepoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 129s 643us/step - loss: 6.0669
# ---Generating with seed: "perhaps serve this age as its mirror and self
# reflector, whe"
# ------temperature: 0.2
# perhaps serve this age as its mirror and self
# reflector, wher our au to ono on ts ao  one or itr too t ar s  on to t e t to  t te anst to  or an to ar ter te t an to to ana ore sto tou an  ore t e oor to att  ane tee tou ar a tou t to to te too tar tooee to te  te  oe tt te  an t a  o ton t one oone aer to to ea tooe ton o ore t oen  on ae  to  on an te t on  o tite in o ts te t t  or  t an toer  o  to to ooore to as to ton er ta a  te to to t aes te on to------temperature: 0.5
# o  to to ooore to as to ton er ta a  te to to t aes te on to tn ee sor n t a torear aot ore t anee tt intr tto t  o o s t st or ast s aet onl atit er tee tao tonen an  otr  s roe ter to or  on t t in a t otee tao to  tnt inetsenta t tseron oneoo oo os es eu ers ore ce in to ae  an rettooene tor to toitors ane ta  rao te t an o oones  or  ont tont  t t ts ar iont  te  ae ote oone t e to te tore ta se tinoat aon oe st a ten t  t ruestt toaiser an to  ore ao ------temperature: 1.0
# se tinoat aon oe st a ten t  t ruestt toaiser an to  ore ao le eaer o onrert ano oit ersrsraerenoenrerout onintoee onooa aalrnose t t istot t ss ito ertler tt s aetoetneeilu si at tnsl in io s turrirtsnr e i trioutot s sno s etties tno at ti ou it or sere a itaes soean  a sae  tos aous tor  or sositio s o t itrose ee tan ts an en sslrrenain asot isr te tsr e iniorte tensit s t o nton sn en anaele ann eannt enete tr  ne setn o so n os en oon in ee titsrne o------temperature: 1.2
# ann eannt enete tr  ne setn o so n os en oon in ee titsrne orlaeerien osstseelst sor ar oirseos tta soeors tra  ertaasreneer e oiisnsoaetannere ei oooo on  r ss nn ttsi tue tru e lsea nea lorarroeots auo rusrsioso iseranalsronler cros tni l nrno trrlois tueersuouoot teno ou na  os r n tsonsout etu eo iroeoreesious tr iritson itte e annninteo tr ett satn  oeroanee sant sas oraiao inntus osrio io eter tne titont etie oua  anrn eerssnit to ot enest  anslus enepoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 131s 655us/step - loss: 5.9706
# ---Generating with seed: " made the apologist of
# knowledge [in the abstract]. on this "
# ------temperature: 0.2
#  made the apologist of
# knowledge [in the abstract]. on this tin too too in nen tincanor to  antoor too onrin onn tuouc on turit ton  ont at on oneatonorun ton an n tan tit tecitun tututun ore  ann to a in tin tin so onn on inioon on tunin tuconen e on un toonn a the tur on an tun to  oneisor oon an in in oorn or oole in tin to in tioun ton tia onre in tinin on ancansoe  tuc  inncr ton onnur an oo iner an tun to  in torelinenn tuct an on  on in ton tin on t------temperature: 0.5
# iner an tun to  in torelinenn tuct an on  on in ton tin on tnorit ounoro tre con  o  inctsonrine cnn t n ns csenli ronn n taorerinl olr an oncrons soenos are snoour snin tiinentnn itin teranreitinenes anetun niraut on tole tainioue tte ttonaoan ionr tooes ar aclionre rn tin on oerorinnonior oner totoer ann ono ancn an tane tnun in  an  ore strinenoir titln onlito tun sntoinirin trerre i tne teaner onrin so  uroro insan to  an sneitinonoil  areuleariisn too------temperature: 1.0
#  onrin so  uroro insan to  an sneitinonoil  areuleariisn toor l  tnniitets osit inno ecut eorrorl oasriaaane on inis ton tent one t tunnenerono unilrenuteasinale al re artoer satinan aret rnelaonain he oot suast aisatitiraure eit iss aa tour s o s orrinst  to ounintriririlo  anoasntuouo tiein n araa asser iior tino anorao rionet inouti tonitirorilo onoritilitins anreiss tieeasrou nn l ioiiit tirinnuitise sor arioetole t otleairoiri  ouo  orl inonra  sn oni------temperature: 1.2
# nuitise sor arioetole t otleairoiri  ouo  orl inonra  sn onirelitu i in tereroioituon ro  sitiirtn nenssneno  enut rnotorr are crisoenrnriai taneineaooie liurnoinsititinan aoa ioe ssoelinnn nort as rn t tot taiti  lnle nutosanatnor ea tucate laar noern oeerrioe an ooanotwerrasecan tuoaertatisneoraoertlas ons un  tuclou  ascesesinens it inte neroei ore srtulitint saseruo tiscals ttusioas arnsanalioitooittr oos rrelsnte ooest nr on sncut nrnor ltunatisolle iepoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 130s 647us/step - loss: 5.8606
# ---Generating with seed: "hing of this pudendum: the latter may, consequently, be prom"
# ------temperature: 0.2
# hing of this pudendum: the latter may, consequently, be prom in annn s tes an an t an se aa anen tane tend and antie tecane san an ten ane  ann anin  an te  an  an an san on tn tes tan act e ane ane tan te an ine an an sn an an ted an nale an anne en tnnnnt  on totinn  ane te oe s  en teanianst an ticen an o nn  t t  it adin t t t andte t t nn t n ar toneand ant  and in sone the  an an an see  ane n t  an to tre conee an an t t no an  antein tn se an t an ------temperature: 0.5
#  n t  an to tre conee an an t t no an  antein tn se an t an sase ninin tensaneea ae oo tir anda iarennan anne al t anon tt t anane anne s nline tean tsonanraneisne oin inns itenn snunt tono anlasnn ns on atint sn sninn iclearen enne  an  aen tin ono tieeinineeed en an tian t se se a in tae enr ac teae neen anenn tn s tne attensane tssoe anunnan in se eris noes ocsane anre suion init an aon tn te iitnthes an ioeisain  naon an anneeran tn an alnieo anin anin------temperature: 1.0
# ...
# o t stht te t ian a tt t ihen an ne t  het ithe siil th i thei t c hshre thouoteut thnil tn aeiithiuc a chs tonu tin ou rets nthi nele sh ns sntotell  ritethie tis haatthlil iits  a the tenhtr hul    oe t ols ie u hhh lanlit i aln o  iourhtse o  t lstrnn  a nul itsll hot uo tshsee tott hell iril oe th cnul us ihesas in  s netiuthi o o thicrastn ot o turhoueis hnse r ll cot s t toe ch s hno oa sn titt ihi th aree ente s oaete u i o hi hhan h on hsinoort tna------temperature: 1.2
# itt ihi th aree ente s oaete u i o hi hhan h on hsinoort tnatiasinthourc etrlt asrea ehe tinl cinsresal ialt enc tseilerh   h cou t solo ao i oteth rhs rilius scloool thh iei us ioelthoon hssert o hhaeehi  iareni euethie sit oto h ul  anat oar at totrs toc urlui thnsnealishaesh real i ana at sr i ans uee oea re i nthaielt cu  se os tstith salihhh ha   ot i in nrase an otcthtsa  iteueslei ti otain io alle  thiss hesit ri l ul riciti sueesiinat uo  inii  ornepoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 134s 667us/step - loss: 5.1801
# ---Generating with seed: "very hand that lays hold of him shrinks back!--and for that "
# ------temperature: 0.2
# very hand that lays hold of him shrinks back!--and for that tot t  aerth  or e ten  there the o hon  an e ar t toe  one  thee ee th or ot eeutter orh toretore ente e ant onot  thae aostoner ou cou ioteo  oen  o te an the to  tho th taere  ane an th(  an o to o  one tee ont  err the  aon on tenth
#  aun ot e ourte teetq tatteirte(reree onr ther oo et e t eor arteooto ton te anarto et te artet thnen an  rhre  o h the  te  the the ter ooen aree eees tnnt tneree------temperature: 0.5
# n  rhre  o h the  te  the the ter ooen aree eees tnnt tnereeac iot eon( to toeco th k doreotoun ane ere  toute ooul o   je are  io an aneth ront at eseerie e  to, nhcu   ont urral o sor oet(aiteeeicea uou tossenerle ar tie  tesetanrono roensot th cnrr eneror ote the ho i the teno  ietan thte oo  ere h e tus onrore  ancntt anellun( an th on  o t oesto oole orol ue atisotore  an ater aron atin osaetterheeitrothe h ote ho 'ctkeor tha t an iro te eio al sste j------temperature: 1.0
# terheeitrothe h ote ho 'ctkeor tha t an iro te eio al sste joseonhninonc uccr cho  t c uorrlcaernh ealoeeoeucatoerasic anntarctctosoo ceoto cor en ono  e eritsa erncee uoloul e  ttle eone oineruretol hatt ooonetthasousanaun rntoatceotonar ernrnirea(nes ae soenoch ou ertu teonelithioruirat n  eeerileers anheao(asoo icn icli lou o ao nressoearinttccn ctoutelstnl tecn at thurouno rhell an corsisioo shatorhset crstorte se ac(ottle orathninatouresaeostthal or o------temperature: 1.2
# hatorhset crstorte se ac(ottle orathninatouresaeostthal or o tritshnt  s tell iihhhroleroseto]rou othotnot al incnocnharre rt assroseneosnrnrhul aseuhthanthsna eanett hote oner  n cliorrinianseture tcliir e hnlo cee eclesostroarotnhheta tentthacesoneenuhasen asnhctou h saro erer atestsrsiseta e(ctntt eouolicthr oue  aottlcaiqne seeloiueseonorirs  hee  orheoieiq nclsetc tr ieetsere t  heoiruouce lito rsaoi hiaonaeaturatlreueesahorteooohaalih hncreeocoeautrrepoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 136s 678us/step - loss: 5.2361
# ---Generating with seed: " he may feel as sinful as
# possible. if this feeling had not "
# ------temperature: 0.2
#  he may feel as sinful as
# possible. if this feeling had not an  thit the the c th set  thhth theroes  t in tth t  t or te t inc th te irh t th th ther r t  thin hh there  the in i h inin ts iht ir in   r th r c the or  tenth the in the th t a rse l ce tri  ori ot iht ith r in o   in in thrr tor tir in itt thorithen tin onst te e r r uont hond te t thre in  t th r.su thr is chit theh h tor tho e hea  o rr t orcre t ouo o in it i  tuhere het  che the  ti th ------temperature: 0.5
# a  o rr t orcre t ouo o in it i  tuhere het  che the  ti th r  cre surr t sin rtrn t er t int t nr t cther thin hatian th th and inin retht e tre iissio c iis  re is r sa he s  irie anstierust ec coor  oor ito o ass  urce tooor hunh hth cc r one oc ho  t t the tin tsheittht oucle tr i aas  tee herir tuc  rt ntcuu  onh  sto  eu ihi  oeler a!a rr  onrin  c tatunip s e ttrec trt th sortan tn h atrr  crt dic s  whthitth tuste o t uore crt o t h     hanin un t ------temperature: 1.0
# crt dic s  whthitth tuste o t uore crt o t h     hanin un t n hner ha  oou c se crnossteactnind til uasos atnntt horoi h irenecusit ecslronachit erts cttetontienure  trrtheinllstcoicn  ice a tsoua et   rl a nonliinniisttonrarte tohttorr itti o ioceh toareec ucatu atos ronoetcosestsrolnt thu  hrerrucsus e tcherta leateriutssu oth ece an(tunctatco nctriorriathain iouart e  hore ntiraht oa hu arcst  rortci  uoe cesnolue rithano e  icaht cs eth ireotehoc el to------temperature: 1.2
# rortci  uoe cesnolue rithano e  icaht cs eth ireotehoc el toecti ir tt ossn wrut utthurrtclirit etnto hr iin itatorilecusoisanhaiut tuaearc ch tinncrartas ct icisoeitrt olloticetcortrecte iorirt untsnohosr t liosi ioon ouoit cnhtntthhe aiounertlitunit  rilo arerauo t susha iiutis r tan sin eciceto rt  rnctluth cnsit rothtohltset s  ticn leata tnsoaree nontcsicuh shuc a oorecc se arcanensoice earr  saousn tur ehchene osaiss r irtls nutothin oitius a osuu neepoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 133s 664us/step - loss: 5.2471
# ---Generating with seed: "situation had to be increased enormously, his inventive facu"
# ------temperature: 0.2
# situation had to be increased enormously, his inventive facun  aon  an ao t on eoe ee too tanne  o tnt on  tor  eno se en an  oot oa ete a an senettheotton  ano n heo tatten an ten tho e te ontte thee  he thne tee or t inthen ooon sthth tet t eth oc tt ohe  t t erecet an an e   ont the  tonenn on ant o  te theen t  ant a tt   tat  tht a t t oheansnene  on  ton  at ca an ansn one an  ananc  thenon  a aneon  ananeo  to art antho  on an ans ton on en   on enn------temperature: 0.5
#  a aneon  ananeo  to art antho  on an ans ton on en   on enn thalon  to oe eito ann en i ttns  an en en an tnan  nto a lo  an a onc in orell ero see a thes atsot int toe e eantnolee on  ne ne nn t a teee un  an eonoi saarsthe  t  iser antass io an inoroonnta coaloini h   hennn the int a a e on  in onor on ooniar th co ei ts t t te s  h tone srn n aal tane onor i t hsthencr  la aan tha ter   e on e i a t e at sth he elo as te tcnronon tin  an  ont ontar e e------temperature: 1.0
#  i a t e at sth he elo as te tcnronon tin  an  ont ontar e eiunee oro ost erin  conssoac aratiooonerheel thnnhencuhlera ti ou oneett cess tte inthr onllottirtnoln senser  rossiancthettatt es lel   oni  otthh  sooechs elar no r atanoeareacer nir  aute tt ceserirn elersotl int tte  ana hthhn  et reoa   sol  oncate coel ecersn eeis tactes eris tnonant na  rceh onstr rheho hr alttiserwnrs o  cote lltc on tsto arisntatastunt  ohancsesheecent naoie oe  ahr anhsn------temperature: 1.2
#  on tsto arisntatastunt  ohancsesheecent naoie oe  ahr anhsnonoes ion oe at onro usclls stt ne alnclsciehois ienanto oosnosl th ixtianlti  cthesrentaisontuherinceoeshnths itrseoesu  eslooctitstesstlnananacon o t ottel olnsc oe tonn aernoteinc thastaeslenltteth an  tas at sttn anctaso at toonrritesll l anthtoen uanint thenah ianta  nc  antstann ne aan   haeenoneto e istsneitrer ihsaletni tnaurthasalgu h ee  coe eo  at arsen er tasrl  s aslseoan  ohenssicuseepoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 136s 680us/step - loss: 5.2101
# ---Generating with seed: "ant exercised on
# german philosophy, and especially to ignore"
# ------temperature: 0.2
# ant exercised on
# german philosophy, and especially to ignore  there hotwhee teetithith hthtt th th
# oth t et thehe th e it to thithttet atentrthet t er the  thwhrto thhthet atir itheterh( the or q thld th heer the hetit e.an   thetnor theatethe it h therw t hote a  hthe  hrthanthee hine ithereththt helee thee he te itithethth ere ohec thhal thhtre t t he
# er ath hetithtthe it orerthe  oh the the es t tt hetttithe tthan av tth tthei an thet theth he thr tet t------temperature: 0.5
# t tt hetttithe tthan av tth tthei an thet theth he thr tet t her as tt tkr tinrertt i chilertthhereth a heritheinotatise isnirt irerat lth o oo oi t en there hositres ht thiz theriltreerin sta iettaht the ees inswe e  rdee thttthee tht trecct ias  hthinthourturethit the he ti t tthee treths thttero  ure ser t thes hoincos  t"etst te alnireth irss thtt thinre hhft  thinherit ah he ct
# hoati:se  rt  theli thh sebcal  erilehestee thet  atithe titerthtoreooekst------temperature: 1.0
# theli thh sebcal  erilehestee thet  atithe titerthtoreooekste aninss htaa au al it rihiratthtthin th  ose  eshisliure ro l  eh oin litoreinenss  as ethnnhii uot rtourti ithhrfssiell arhts t aeoliesoos atihcortil  h titjurhuherthar strthelhitttrsceno iene  e js tsutsntscintie aorhhcit  uetho harsreee thi tat ttthea  rhs aut tothhuirti thehlthek ii ecer"olse ucenolioo antos oe tot or ttstthtqnhhi tsoi itheccuireotarl hthelthetth rittte ttjteioe aiiaho esithr------temperature: 1.2
# oi itheccuireotarl hthelthetth rittte ttjteioe aiiaho esithr asi-is aiteetieccanulshi  chn ;slirhitrlort toralttcasiutuinerorauitaluatthrir tt thell nacttrosteiciian ais ts ul anoseotearlttetiourertrrias ieeltooltotslceslatesecntasiseihlcltiee  oeeha t oolhësttiseoliaheisheni  ttcltil aar   a toc eiialh oaru ao thicile hn ou ooosnntisllherreurlcuhh-cltuerouit suin ralualsc rcjhi u  tottosnitit untonher  rna itntsintoaur not tho tserr ee ee sttlilethll  s iepoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 134s 669us/step - loss: 5.1965
# ---Generating with seed: ", became gradually stricter towards
# woman, in short, more or"
# ------temperature: 0.2
# , became gradually stricter towards
# woman, in short, more ore al an lllh i hel ere e ananane ton hn  e thel hl al h el on ane a e an e hlthe t arie e ea  the rnale e thn alil h the oe th ieetin the ne oniri loe  e a hall  hr an tr an a othe in e h  n a t i an onnat the  inelo an  roele e e  iea e thel inel e o  thaee ane i  nt an ili en ar on en lll in iontain on he n hi ine thl tna a i  el tit  theni in te an or  an ll inhi  in ehe  on th a ere leie  al e------temperature: 0.5
# heni in te an or  an ll inhi  in ehe  on th a ere leie  al el  o ieen e s t ithe oennseolna lono ile aa  heree  onane ianithicn h er a  hn ilae aton aniae llo eno ane o thisn  n alons he lonel  earealsn alth e he iithl t ieleilio etn inon sn l conone to t eo saha t  anha i a ran ae h ehensooine ee naleiiethlt ie a ain letils eelieee can i aelihne oal anthiana h ie serlo aalinlei on thinqaeatissee   eh he ie aolo the he   hehe a ione thll  sn iiin i liiaa t------temperature: 1.0
#   eh he ie aolo the he   hehe a ione thll  sn iiin i liiaa tn leeealothe nlean ar oo eerat ttoioioecreltiti  sor tr eorooutaureeoru reianrier neents sr iiaeeie  talatisooinahtonnu thahtherslthilel aniillsihals tio n leelts saoeia inl aaiirl s e sa tiasoeuaneunhlk r  thaltses tarsins as o t o hlailearle tal t rneuninhe rnorr iththnlet iis t sesall theh thheecteuactne  ttheal onssieee ena l acncnrolt an h anrel eitheath aelleir snlese thnolireae thonear a ai------temperature: 1.2
# t an h anrel eitheath aelleir snlese thnolireae thonear a aitolliaiin asntithennreiohottellelslslhl relhrotteeat the o then ertsernietitatoni osislriiiianenlnn eit ieonen n  ithssh is ot oneat orsthatthithian ocahonla cheoo t isinlro aeori olaa alh nela  eronoliiahtrseenrutle  nt  aoth l thnoonh n saet esell e hl touuei soielcsrr eien anrchen alxsth th  rnthtranscniecinoha cioaeil tllsee rtoririocuraltite te arenuriilaucialite=o s ae riu io  uiha in6hen ocepoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 133s 666us/step - loss: 5.1830
# ---Generating with seed: "or the grumbling,
# vexed, revolutionary slave-classes who str"
# ------temperature: 0.2
# or the grumbling,
# vexed, revolutionary slave-classes who str e a a e ose ao o sures an e o the  ar   te eo ono   to aeere aree a e hhe  our h a  ahe a e as a a a a as  a ous  s ao e han an ol ono t oure to o  oot the  ao e e   ou  here h   o t oo a e a aue t o  he o her    e eo or  s ar e e at ao a s e a e a ohe   es o a o oor a  outha ohere a e e  e  oe o aero e oee he   he oun e e  ree oue als  har o a  o he e o a ou aore t a  a  or   a oo o o ar an ae e------temperature: 0.5
# har o a  o he e o a ou aore t a  a  or   a oo o o ar an ae e  o hea eca  oe ilr el the re ase  to o  ooru th ao e ale e eieese   ain  hor tate ansoau eureseohe ose e arre e ho he is se noo oun  r o a ore ans o e he heos the e ts a ootousae ooe hal  to  ooeoe  oerlatse  seosre ono  oe  iee  oeah he  oeteo se it ale ul  ast han otohe o ise eneo  oher   ue ou sla s i le ce h uo io  ar are io  o oeenere  osseo r   a e   sen  s e e  osoe us an    a ao er r ahot------temperature: 1.0
# re  osseo r   a e   sen  s e e  osoe us an    a ao er r ahotreeteohaisu he troreoti  ul ousthiresasenrle seee rioesto oarerorot ces he unllor oec oun s  thall otealsoenenn ou c outlr eos ouroies o ae oru o e at eoes he  ao h en ahiiureatitusicteatcroon e useal i  ouese esne er esheareora aus utins he a sia oatuet er noa t tnur isoantealiuenue  soroeetithirssote eutlleuasthaheo has rorierte eh eee iaeic iioaunu hho atousiuu  o tthao ouroueruio ho  ine  lo e------temperature: 1.2
# iaeic iioaunu hho atousiuu  o tthao ouroueruio ho  ine  lo eleo hat aoe i aeseceeiesrne arel ahaousic tochailo eohaistio ourttoaourour aecea hesros eutoureeso ttiahsl ortr ao oea laeauureoestutuleos  eot si n  t h eo oou  oureaase tealoresraleisteoh cnetilreatcohaorll s o elr e  hss neotlnselreouoesietnussht in t hul teetahu surahunosohssoterot e rln r elr  or  hir i honeatao coresctishn aslst hos  encar ealesoaia anhonteesthte orito  touoth ornrrhonuull tepoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 134s 672us/step - loss: 5.1472
# ---Generating with seed: "lso belongs to the old false adornment, frippery, and
# gold-d"
# ------temperature: 0.2
# lso belongs to the old false adornment, frippery, and
# gold-d th tn iseno io t or e int ene  ten ant theat  the anin e  an en  anan aenein anthtieener an t anse ine  onen t inele s inen ini that  ai ane o ee onenonel oun t on  enounr an thounes oiune ain anes  thethe  thine or s hene thener an oue en a  ti en  he  o thihen the thene nt eh tene  nen nt tintese se entous etinen as anese oesser iin tin the an the en in  tine an  ane hen  t ans oe e en t ei  oo------temperature: 0.5
# n the an the en in  tine an  ane hen  t ans oe e en t ei  ooine  oun soreseilin  in ans o eo thrherssentet heora  onsesess hi thit ueeea int eirethean orthhnleler on enerons a ineseritnae ati eri ther tt si ontnot ts onest ho antona s  hin ta eee th an   tos ie aieenent ue thit ari ose hae an i nthos a htn   au iseisssoruen heinton one iini in eon inan ht es hean anl tt asene n ou  iennne ethnhoses otret ir isen eranleiec nnusoioi iouni as htisen hacnst a ------temperature: 1.0
# s otret ir isen eranleiec nnusoioi iouni as htisen hacnst a inis unetnaernlssuns a tnur t ticesse ss istr ithnau an lt auc onant orna nneceielinsse lat ane ai eunn tea e eu arioun  onns i ouons ruoisuncnionohses tiu lec aocoro inoro usrote ersettht  st o  esiis re asus nrireturrei tanlittillrut anh rrasuna oh r ohist ts teoausr oousounnsuorso esotin erhaniatio ousrilsise essustureihant sle hetouunshetoit a te asesehuhitolh ririrsa neess orun einusenorluiia------temperature: 1.2
# shetoit a te asesehuhitolh ririrsa neess orun einusenorluiianunin e ontonnethe otauisino seei leisteen tu irusut arcelaeo r halethe nasscis itatines as trst eoeel hon rnshoseitatherl hsesnni rroairlirson n ntiahosnnnlssenthsrollol etointnt rs hherira  l rs s t rtosn iau sniines so s  oen hn netsior rau letiouh ote ranhu oieteni t ieetin cutascar tese srn inhnt oia uisell soas ororerencsctausaiterlntianns allhss st ilurltts u ucnoroat a eiol itinreoaisnss e
